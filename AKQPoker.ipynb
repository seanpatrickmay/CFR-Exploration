# %%
# Imports
import random
import numpy as np

# %%
# Data Definitions
CHECK = 0
# For now, fixed bet size.
BET = 1
NUM_ACTIONS = 2 # Check, Bet
BETTING_ROUNDS = 4 # Pre, Flop, Turn, River

# %%
class PokerNode:
    def __init__(self):
        self.infoset = ""
        self.regretSum = [0.0] * NUM_ACTIONS
        self.strategy = [0.0] * NUM_ACTIONS
        self.strategySum = [0.0] * NUM_ACTIONS

    def getStrategy(self, realizationWeight):
        normalizingSum = 0
        for action in range(NUM_ACTIONS):
            if self.regretSum[action] > 0:
                self.strategy[action] = self.regretSum[action]
            else:
                self.strategy[action] = 0
            normalizingSum += self.strategy[action]
        for action in range(NUM_ACTIONS):
            if normalizingSum > 0:
                self.strategy[action] /= normalizingSum
            else:
                self.strategy[action] = 1.0 / NUM_ACTIONS
            self.strategySum[action] += realizationWeight * self.strategy[action]
        return self.strategy

    def getAverageStrategy(self):
        averageStrategy = [0.0] * NUM_ACTIONS
        normalizingSum = 0.0
        for action in range(NUM_ACTIONS):
            normalizingSum += self.strategySum[action]
        for action in range(NUM_ACTIONS):
            if normalizingSum > 0:
                averageStrategy[action] = self.strategySum[action] / normalizingSum
            else:
                averageStrategy[action] = 1.0 / NUM_ACTIONS
        return averageStrategy

    def __str__(self):
        avgStratsNice = [round(num, 4) for num in self.getAverageStrategy()]
        return f"{self.infoSet:<40}: Pass: {avgStratsNice[0]} Bet: {avgStratsNice[1]}"

# %%
# A history node contains: previous node, pot size, previous action
# A history node has methods:
# historyLength - length of node chain
# prevAction is the previous bet, zero if checked

class historyNode:
    def __init__(self, last=None, prevAction=0, bettingRound=0):
        self.last = last
        if self.last:
            self.pot = last.pot + prevAction
        else:
            self.pot = 0
        self.prevAction = prevAction
        self.bettingRound = bettingRound

    def historyLength(self):
        if self.prevAction == -1:
            return 0
        if roundTerminalNode(self.last) != 0:
            return 1
        else:
            return 1 + self.last.historyLength()

    
    
    def niceString(self):
        if self.last == None:
            return ''
        if roundTerminalNode(self.last):
            return self.last.niceString() + '| ' + formatAction(self.prevAction)
        else:
            return self.last.niceString() + formatAction(self.prevAction)
        
    
    def __str__(self):
        if self.last == None:
            return ''
        return str(self.last) + str(self.prevAction)

def formatAction(action):
    if action > 0:
        return 'B' + str(action) + ' '
    elif action == 0:
        return 'X '

# %%
# Returns boolean if player is winning
# Current inputs: cards for player, cards for opponent
# Cards is currently just 1 card though
def playerWins(player, opponent):
    return player > opponent

# Some example history sequences:
# 0 0 (Check Check)
# 1 1 (Bet Call)
# 1 2 2 (Bet Raise Call)
# 1 2 3 4 4 (Bet Raise Raise Raise Call) # Due to cases like this, should add real time pot calculations
# 1 2 0 (Bet Raise Fold)

# Is this historyNode a terminal node?
# Terminal Cases:
# Call a bet on River (round=3)
# Fold any time
def terminalNode(historyNode): # Returns 0 for no, 1 for fold, 2 for showdown
    if historyNode.historyLength() < 2:
        return 0
    # If check check or bet/raise call (On River only!) - Showdown
    elif historyNode.prevAction - historyNode.last.prevAction == 0 and historyNode.bettingRound == 3:
        return 2
    # If fold
    elif historyNode.prevAction == 0 and historyNode.last.prevAction not in [0, -1]:
        return 1
    return 0

# 0 is no, 1 is yes
def roundTerminalNode(historyNode):
    if historyNode.historyLength() < 2:
        return 0
    elif historyNode.prevAction - historyNode.last.prevAction == 0 and historyNode.bettingRound < 3:
        return 1
    return 0

# %%
class PokerTrainer:
    def __init__(self):
        self.nodeMap = dict()
    
    def train(self, iterations):
        cards = list(range(1, 4))
        util = 0.0
        for iteration in range(iterations):
            random.shuffle(cards)
            util += self.cfr(cards, historyNode(None, -1, 0), 1, 1)
        print("Average game value: ", util / iterations)
        for node in sorted(self.nodeMap.values(), key=(lambda node: node.infoSet)):
            print(node)

    def cfr(self, cards, history, p0, p1):
        plays = history.historyLength()
        player = plays % 2
        opponent = 1 - player

        # Getting return payoffs for terminal states
        if (terminalState := terminalNode(history)) != 0: # Walrus 😎
            # If folded
            if terminalState == 1:
                return -history.pot if player == 1 else history.pot
            # Showdown
            elif terminalState == 2:
                return history.pot if playerWins(cards[0], cards[1]) else -history.pot

        infoSet = str(cards[player]) + ': ' + history.niceString()
        
        # Get info set node, or create it
        node = self.nodeMap.get(infoSet)
        if node == None:
            node = PokerNode()
            node.infoSet = infoSet
            self.nodeMap[infoSet] = node
    
        # Recursively call cfr with additional history and probability for each action
        strategy = node.getStrategy(p0 if player == 0 else p1)
        util = [0.0] * NUM_ACTIONS
        nodeUtil = 0
        for action in range(NUM_ACTIONS):
            nextHistory = historyNode(history, action, history.bettingRound + 1 if roundTerminalNode(history) == 1 else history.bettingRound)
            if player == 0:
                util[action] = - self.cfr(cards, nextHistory, p0 * strategy[action], p1)
            else:
                util[action] = - self.cfr(cards, nextHistory, p0, p1 * strategy[action])
            nodeUtil += strategy[action] * util[action]
    
        # Compute and accumulate cfr for each action
        for action in range(NUM_ACTIONS):
            regret = util[action] - nodeUtil
            node.regretSum[action] += (p1 if player == 0 else p0) * regret
    
        return nodeUtil

# %%
trainer = PokerTrainer()
trainer.train(10000)
# Out:
# Average game value:  0.33596134255700916
# 1:                                      : Pass: 0.9965 Bet: 0.0035
# 1: B1                                   : Pass: 0.9999 Bet: 0.0001
# 1: B1 B1                                : Pass: 0.8804 Bet: 0.1196
# 1: B1 B1 | B1                           : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1                        : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | B1                   : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | B1 B1                : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X                    : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X B1                 : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X B1 B1              : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X X                  : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X X | B1             : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X X | X              : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | B1 B1 | X X | X B1           : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X                            : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1                         : Pass: 0.0679 Bet: 0.9321
# 1: B1 B1 | X B1 B1                      : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | B1                 : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | B1 B1              : Pass: 0.9636 Bet: 0.0364
# 1: B1 B1 | X B1 B1 | B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X                  : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X B1               : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X B1 B1            : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X B1 B1 | B1       : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X B1 B1 | X        : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X X                : Pass: 0.8502 Bet: 0.1498
# 1: B1 B1 | X B1 B1 | X X | B1           : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X X | X            : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X B1 B1 | X X | X B1         : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X                          : Pass: 0.8264 Bet: 0.1736
# 1: B1 B1 | X X | B1                     : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | B1 B1                  : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | B1 B1 | B1             : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | B1 B1 | X              : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X                      : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X B1                   : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X B1 B1                : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X X                    : Pass: 0.895 Bet: 0.105
# 1: B1 B1 | X X | X X | B1               : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X X | X                : Pass: 0.5 Bet: 0.5
# 1: B1 B1 | X X | X X | X B1             : Pass: 0.5 Bet: 0.5
# 1: X                                    : Pass: 0.9914 Bet: 0.0086
# 1: X B1                                 : Pass: 0.0001 Bet: 0.9999
# 1: X B1 B1                              : Pass: 0.0174 Bet: 0.9826
# 1: X B1 B1 | B1                         : Pass: 0.9912 Bet: 0.0088
# 1: X B1 B1 | B1 B1                      : Pass: 1.0 Bet: 0.0
# 1: X B1 B1 | B1 B1 | B1                 : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | B1 B1              : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X                  : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X B1               : Pass: 1.0 Bet: 0.0
# 1: X B1 B1 | B1 B1 | X B1 B1            : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X B1 B1 | B1       : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X B1 B1 | X        : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X X                : Pass: 1.0 Bet: 0.0
# 1: X B1 B1 | B1 B1 | X X | B1           : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X X | X            : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | B1 B1 | X X | X B1         : Pass: 0.0 Bet: 1.0
# 1: X B1 B1 | X                          : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1                       : Pass: 1.0 Bet: 0.0
# 1: X B1 B1 | X B1 B1                    : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | B1               : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | B1 B1            : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | B1 B1 | B1       : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | B1 B1 | X        : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X                : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X B1             : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X B1 B1          : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X B1 B1 | B1     : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X B1 B1 | X      : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X B1 B1 | X B1   : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X X              : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X X | B1         : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X X | X          : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X B1 B1 | X X | X B1       : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X                        : Pass: 0.9994 Bet: 0.0006
# 1: X B1 B1 | X X | B1                   : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | B1 B1                : Pass: 0.9694 Bet: 0.0306
# 1: X B1 B1 | X X | B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | B1 B1 | X B1         : Pass: 0.0158 Bet: 0.9842
# 1: X B1 B1 | X X | X                    : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | X B1                 : Pass: 1.0 Bet: 0.0
# 1: X B1 B1 | X X | X B1 B1              : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | X X                  : Pass: 1.0 Bet: 0.0
# 1: X B1 B1 | X X | X X | B1             : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | X X | X              : Pass: 0.5 Bet: 0.5
# 1: X B1 B1 | X X | X X | X B1           : Pass: 0.0 Bet: 1.0
# 1: X X                                  : Pass: 0.9991 Bet: 0.0009
# 1: X X | B1                             : Pass: 0.9998 Bet: 0.0002
# 1: X X | B1 B1                          : Pass: 0.5073 Bet: 0.4927
# 1: X X | B1 B1 | B1                     : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | B1 B1                  : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | B1 B1 | B1             : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | B1 B1 | X              : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X                      : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X B1                   : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X B1 B1                : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X X                    : Pass: 0.5145 Bet: 0.4855
# 1: X X | B1 B1 | X X | B1               : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X X | X                : Pass: 0.5 Bet: 0.5
# 1: X X | B1 B1 | X X | X B1             : Pass: 0.5 Bet: 0.5
# 1: X X | X                              : Pass: 0.9998 Bet: 0.0002
# 1: X X | X B1                           : Pass: 0.0002 Bet: 0.9998
# 1: X X | X B1 B1                        : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | B1                   : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | B1 B1                : Pass: 0.9999 Bet: 0.0001
# 1: X X | X B1 B1 | B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X                    : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X B1                 : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X B1 B1              : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X X                  : Pass: 0.9999 Bet: 0.0001
# 1: X X | X B1 B1 | X X | B1             : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X X | X              : Pass: 0.5 Bet: 0.5
# 1: X X | X B1 B1 | X X | X B1           : Pass: 0.5 Bet: 0.5
# 1: X X | X X                            : Pass: 0.9998 Bet: 0.0002
# 1: X X | X X | B1                       : Pass: 0.9999 Bet: 0.0001
# 1: X X | X X | B1 B1                    : Pass: 0.5 Bet: 0.5
# 1: X X | X X | B1 B1 | B1               : Pass: 0.5 Bet: 0.5
# 1: X X | X X | B1 B1 | X                : Pass: 0.5 Bet: 0.5
# 1: X X | X X | B1 B1 | X B1             : Pass: 0.5 Bet: 0.5
# 1: X X | X X | X                        : Pass: 0.9999 Bet: 0.0001
# 1: X X | X X | X B1                     : Pass: 0.5 Bet: 0.5
# 1: X X | X X | X B1 B1                  : Pass: 0.5 Bet: 0.5
# 1: X X | X X | X B1 B1 | B1             : Pass: 0.5 Bet: 0.5
# 1: X X | X X | X B1 B1 | X              : Pass: 0.5 Bet: 0.5
# 1: X X | X X | X B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 1: X X | X X | X X                      : Pass: 0.9999 Bet: 0.0001
# 1: X X | X X | X X | B1                 : Pass: 1.0 Bet: 0.0
# 1: X X | X X | X X | X                  : Pass: 1.0 Bet: 0.0
# 1: X X | X X | X X | X B1               : Pass: 0.5 Bet: 0.5
# 2:                                      : Pass: 0.994 Bet: 0.006
# 2: B1                                   : Pass: 0.9991 Bet: 0.0009
# 2: B1 B1                                : Pass: 0.3873 Bet: 0.6127
# 2: B1 B1 | B1                           : Pass: 0.915 Bet: 0.085
# 2: B1 B1 | B1 B1                        : Pass: 0.0782 Bet: 0.9218
# 2: B1 B1 | B1 B1 | B1                   : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | B1 B1                : Pass: 0.165 Bet: 0.835
# 2: B1 B1 | B1 B1 | B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | B1 B1 | X B1         : Pass: 0.4274 Bet: 0.5726
# 2: B1 B1 | B1 B1 | X                    : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | X B1                 : Pass: 0.9342 Bet: 0.0658
# 2: B1 B1 | B1 B1 | X B1 B1              : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | X X                  : Pass: 0.7403 Bet: 0.2597
# 2: B1 B1 | B1 B1 | X X | B1             : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | X X | X              : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | B1 B1 | X X | X B1           : Pass: 0.9141 Bet: 0.0859
# 2: B1 B1 | X                            : Pass: 0.915 Bet: 0.085
# 2: B1 B1 | X B1                         : Pass: 0.9837 Bet: 0.0163
# 2: B1 B1 | X B1 B1                      : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | B1                 : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | B1 B1              : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X                  : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X B1               : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X B1 B1            : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X B1 B1 | B1       : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X B1 B1 | X        : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X X                : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X X | B1           : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X X | X            : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X B1 B1 | X X | X B1         : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X X                          : Pass: 0.9648 Bet: 0.0352
# 2: B1 B1 | X X | B1                     : Pass: 0.0465 Bet: 0.9535
# 2: B1 B1 | X X | B1 B1                  : Pass: 0.6488 Bet: 0.3512
# 2: B1 B1 | X X | B1 B1 | B1             : Pass: 0.0244 Bet: 0.9756
# 2: B1 B1 | X X | B1 B1 | X              : Pass: 0.9756 Bet: 0.0244
# 2: B1 B1 | X X | B1 B1 | X B1           : Pass: 0.7926 Bet: 0.2074
# 2: B1 B1 | X X | X                      : Pass: 0.9535 Bet: 0.0465
# 2: B1 B1 | X X | X B1                   : Pass: 0.9916 Bet: 0.0084
# 2: B1 B1 | X X | X B1 B1                : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X X | X B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X X | X B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X X | X B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 2: B1 B1 | X X | X X                    : Pass: 0.9504 Bet: 0.0496
# 2: B1 B1 | X X | X X | B1               : Pass: 0.0244 Bet: 0.9756
# 2: B1 B1 | X X | X X | X                : Pass: 0.9756 Bet: 0.0244
# 2: B1 B1 | X X | X X | X B1             : Pass: 0.9248 Bet: 0.0752
# 2: X                                    : Pass: 0.9978 Bet: 0.0022
# 2: X B1                                 : Pass: 0.9999 Bet: 0.0001
# 2: X B1 B1                              : Pass: 0.309 Bet: 0.691
# 2: X B1 B1 | B1                         : Pass: 0.1186 Bet: 0.8814
# 2: X B1 B1 | B1 B1                      : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | B1                 : Pass: 0.0673 Bet: 0.9327
# 2: X B1 B1 | B1 B1 | B1 B1              : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | B1 B1 | B1         : Pass: 0.0361 Bet: 0.9639
# 2: X B1 B1 | B1 B1 | B1 B1 | X          : Pass: 0.9639 Bet: 0.0361
# 2: X B1 B1 | B1 B1 | B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | X                  : Pass: 0.9327 Bet: 0.0673
# 2: X B1 B1 | B1 B1 | X B1               : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | X B1 B1            : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | X B1 B1 | B1       : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | X B1 B1 | X        : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | X B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | X X                : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | B1 B1 | X X | B1           : Pass: 0.0361 Bet: 0.9639
# 2: X B1 B1 | B1 B1 | X X | X            : Pass: 0.9639 Bet: 0.0361
# 2: X B1 B1 | B1 B1 | X X | X B1         : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X                          : Pass: 0.7315 Bet: 0.2685
# 2: X B1 B1 | X B1                       : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1                    : Pass: 0.4939 Bet: 0.5061
# 2: X B1 B1 | X B1 B1 | B1               : Pass: 0.4879 Bet: 0.5121
# 2: X B1 B1 | X B1 B1 | B1 B1            : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | B1 B1 | B1       : Pass: 0.4764 Bet: 0.5236
# 2: X B1 B1 | X B1 B1 | B1 B1 | X        : Pass: 0.5236 Bet: 0.4764
# 2: X B1 B1 | X B1 B1 | B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X                : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X B1             : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X B1 B1          : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X B1 B1 | B1     : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X B1 B1 | X      : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X B1 B1 | X B1   : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X X              : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X X | B1         : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X X | X          : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X B1 B1 | X X | X B1       : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X                        : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | B1                   : Pass: 0.1813 Bet: 0.8187
# 2: X B1 B1 | X X | B1 B1                : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | B1 B1 | B1           : Pass: 0.1107 Bet: 0.8893
# 2: X B1 B1 | X X | B1 B1 | X            : Pass: 0.8893 Bet: 0.1107
# 2: X B1 B1 | X X | B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | X                    : Pass: 0.8187 Bet: 0.1813
# 2: X B1 B1 | X X | X B1                 : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | X B1 B1              : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | X X                  : Pass: 0.5 Bet: 0.5
# 2: X B1 B1 | X X | X X | B1             : Pass: 0.1107 Bet: 0.8893
# 2: X B1 B1 | X X | X X | X              : Pass: 0.8893 Bet: 0.1107
# 2: X B1 B1 | X X | X X | X B1           : Pass: 0.5 Bet: 0.5
# 2: X X                                  : Pass: 0.9999 Bet: 0.0001
# 2: X X | B1                             : Pass: 0.9998 Bet: 0.0002
# 2: X X | B1 B1                          : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | B1                     : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | B1 B1                  : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | B1 B1 | B1             : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | B1 B1 | X              : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X                      : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X B1                   : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X B1 B1                : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X X                    : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X X | B1               : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X X | X                : Pass: 0.5 Bet: 0.5
# 2: X X | B1 B1 | X X | X B1             : Pass: 0.5 Bet: 0.5
# 2: X X | X                              : Pass: 0.9997 Bet: 0.0003
# 2: X X | X B1                           : Pass: 1.0 Bet: 0.0
# 2: X X | X B1 B1                        : Pass: 0.6381 Bet: 0.3619
# 2: X X | X B1 B1 | B1                   : Pass: 0.4968 Bet: 0.5032
# 2: X X | X B1 B1 | B1 B1                : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | B1 B1 | B1           : Pass: 0.4937 Bet: 0.5063
# 2: X X | X B1 B1 | B1 B1 | X            : Pass: 0.5063 Bet: 0.4937
# 2: X X | X B1 B1 | B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | X                    : Pass: 0.7182 Bet: 0.2818
# 2: X X | X B1 B1 | X B1                 : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | X B1 B1              : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | X X                  : Pass: 0.5 Bet: 0.5
# 2: X X | X B1 B1 | X X | B1             : Pass: 0.1962 Bet: 0.8038
# 2: X X | X B1 B1 | X X | X              : Pass: 0.8038 Bet: 0.1962
# 2: X X | X B1 B1 | X X | X B1           : Pass: 0.5 Bet: 0.5
# 2: X X | X X                            : Pass: 1.0 Bet: 0.0
# 2: X X | X X | B1                       : Pass: 0.9988 Bet: 0.0012
# 2: X X | X X | B1 B1                    : Pass: 0.5 Bet: 0.5
# 2: X X | X X | B1 B1 | B1               : Pass: 0.0476 Bet: 0.9524
# 2: X X | X X | B1 B1 | X                : Pass: 0.9524 Bet: 0.0476
# 2: X X | X X | B1 B1 | X B1             : Pass: 0.5 Bet: 0.5
# 2: X X | X X | X                        : Pass: 0.9999 Bet: 0.0001
# 2: X X | X X | X B1                     : Pass: 1.0 Bet: 0.0
# 2: X X | X X | X B1 B1                  : Pass: 0.5 Bet: 0.5
# 2: X X | X X | X B1 B1 | B1             : Pass: 0.5 Bet: 0.5
# 2: X X | X X | X B1 B1 | X              : Pass: 0.5 Bet: 0.5
# 2: X X | X X | X B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 2: X X | X X | X X                      : Pass: 1.0 Bet: 0.0
# 2: X X | X X | X X | B1                 : Pass: 0.9932 Bet: 0.0068
# 2: X X | X X | X X | X                  : Pass: 0.9999 Bet: 0.0001
# 2: X X | X X | X X | X B1               : Pass: 0.8333 Bet: 0.1667
# 3:                                      : Pass: 0.5638 Bet: 0.4362
# 3: B1                                   : Pass: 0.0005 Bet: 0.9995
# 3: B1 B1                                : Pass: 0.9983 Bet: 0.0017
# 3: B1 B1 | B1                           : Pass: 0.0001 Bet: 0.9999
# 3: B1 B1 | B1 B1                        : Pass: 0.148 Bet: 0.852
# 3: B1 B1 | B1 B1 | B1                   : Pass: 0.0 Bet: 1.0
# 3: B1 B1 | B1 B1 | B1 B1                : Pass: 0.0868 Bet: 0.9132
# 3: B1 B1 | B1 B1 | B1 B1 | B1           : Pass: 0.0 Bet: 1.0
# 3: B1 B1 | B1 B1 | B1 B1 | X            : Pass: 1.0 Bet: 0.0
# 3: B1 B1 | B1 B1 | B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | B1 B1 | X                    : Pass: 1.0 Bet: 0.0
# 3: B1 B1 | B1 B1 | X B1                 : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | B1 B1 | X B1 B1              : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | B1 B1 | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | B1 B1 | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | B1 B1 | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | B1 B1 | X X                  : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | B1 B1 | X X | B1             : Pass: 0.0 Bet: 1.0
# 3: B1 B1 | B1 B1 | X X | X              : Pass: 1.0 Bet: 0.0
# 3: B1 B1 | B1 B1 | X X | X B1           : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X                            : Pass: 0.999 Bet: 0.001
# 3: B1 B1 | X B1                         : Pass: 0.9997 Bet: 0.0003
# 3: B1 B1 | X B1 B1                      : Pass: 0.0421 Bet: 0.9579
# 3: B1 B1 | X B1 B1 | B1                 : Pass: 0.0204 Bet: 0.9796
# 3: B1 B1 | X B1 B1 | B1 B1              : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | B1 B1 | B1         : Pass: 0.0104 Bet: 0.9896
# 3: B1 B1 | X B1 B1 | B1 B1 | X          : Pass: 0.9896 Bet: 0.0104
# 3: B1 B1 | X B1 B1 | B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | X                  : Pass: 0.5366 Bet: 0.4634
# 3: B1 B1 | X B1 B1 | X B1               : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | X B1 B1            : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | X B1 B1 | B1       : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | X B1 B1 | X        : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | X B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | X X                : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X B1 B1 | X X | B1           : Pass: 0.4317 Bet: 0.5683
# 3: B1 B1 | X B1 B1 | X X | X            : Pass: 0.5683 Bet: 0.4317
# 3: B1 B1 | X B1 B1 | X X | X B1         : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X                          : Pass: 0.0003 Bet: 0.9997
# 3: B1 B1 | X X | B1                     : Pass: 0.0 Bet: 1.0
# 3: B1 B1 | X X | B1 B1                  : Pass: 0.0001 Bet: 0.9999
# 3: B1 B1 | X X | B1 B1 | B1             : Pass: 0.0 Bet: 1.0
# 3: B1 B1 | X X | B1 B1 | X              : Pass: 1.0 Bet: 0.0
# 3: B1 B1 | X X | B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X | X                      : Pass: 1.0 Bet: 0.0
# 3: B1 B1 | X X | X B1                   : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X | X B1 B1                : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X | X B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X | X B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X | X B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X | X X                    : Pass: 0.5 Bet: 0.5
# 3: B1 B1 | X X | X X | B1               : Pass: 0.0 Bet: 1.0
# 3: B1 B1 | X X | X X | X                : Pass: 1.0 Bet: 0.0
# 3: B1 B1 | X X | X X | X B1             : Pass: 0.5 Bet: 0.5
# 3: X                                    : Pass: 0.9992 Bet: 0.0008
# 3: X B1                                 : Pass: 0.9999 Bet: 0.0001
# 3: X B1 B1                              : Pass: 0.1269 Bet: 0.8731
# 3: X B1 B1 | B1                         : Pass: 0.0555 Bet: 0.9445
# 3: X B1 B1 | B1 B1                      : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | B1                 : Pass: 0.0294 Bet: 0.9706
# 3: X B1 B1 | B1 B1 | B1 B1              : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | B1 B1 | B1         : Pass: 0.0151 Bet: 0.9849
# 3: X B1 B1 | B1 B1 | B1 B1 | X          : Pass: 0.9849 Bet: 0.0151
# 3: X B1 B1 | B1 B1 | B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | X                  : Pass: 0.9706 Bet: 0.0294
# 3: X B1 B1 | B1 B1 | X B1               : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | X B1 B1            : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | X B1 B1 | B1       : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | X B1 B1 | X        : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | X B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | X X                : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | B1 B1 | X X | B1           : Pass: 0.0151 Bet: 0.9849
# 3: X B1 B1 | B1 B1 | X X | X            : Pass: 0.9849 Bet: 0.0151
# 3: X B1 B1 | B1 B1 | X X | X B1         : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X                          : Pass: 0.6146 Bet: 0.3854
# 3: X B1 B1 | X B1                       : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1                    : Pass: 0.4953 Bet: 0.5047
# 3: X B1 B1 | X B1 B1 | B1               : Pass: 0.4908 Bet: 0.5092
# 3: X B1 B1 | X B1 B1 | B1 B1            : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | B1 B1 | B1       : Pass: 0.4819 Bet: 0.5181
# 3: X B1 B1 | X B1 B1 | B1 B1 | X        : Pass: 0.5181 Bet: 0.4819
# 3: X B1 B1 | X B1 B1 | B1 B1 | X B1     : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X                : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X B1             : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X B1 B1          : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X B1 B1 | B1     : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X B1 B1 | X      : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X B1 B1 | X B1   : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X X              : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X X | B1         : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X X | X          : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X B1 B1 | X X | X B1       : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X                        : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | B1                   : Pass: 0.3106 Bet: 0.6894
# 3: X B1 B1 | X X | B1 B1                : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | B1 B1 | B1           : Pass: 0.2253 Bet: 0.7747
# 3: X B1 B1 | X X | B1 B1 | X            : Pass: 0.7747 Bet: 0.2253
# 3: X B1 B1 | X X | B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | X                    : Pass: 0.6894 Bet: 0.3106
# 3: X B1 B1 | X X | X B1                 : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | X B1 B1              : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | X X                  : Pass: 0.5 Bet: 0.5
# 3: X B1 B1 | X X | X X | B1             : Pass: 0.2253 Bet: 0.7747
# 3: X B1 B1 | X X | X X | X              : Pass: 0.7747 Bet: 0.2253
# 3: X B1 B1 | X X | X X | X B1           : Pass: 0.5 Bet: 0.5
# 3: X X                                  : Pass: 0.997 Bet: 0.003
# 3: X X | B1                             : Pass: 0.0001 Bet: 0.9999
# 3: X X | B1 B1                          : Pass: 0.0219 Bet: 0.9781
# 3: X X | B1 B1 | B1                     : Pass: 0.0 Bet: 1.0
# 3: X X | B1 B1 | B1 B1                  : Pass: 0.0112 Bet: 0.9888
# 3: X X | B1 B1 | B1 B1 | B1             : Pass: 0.0 Bet: 1.0
# 3: X X | B1 B1 | B1 B1 | X              : Pass: 1.0 Bet: 0.0
# 3: X X | B1 B1 | B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 3: X X | B1 B1 | X                      : Pass: 1.0 Bet: 0.0
# 3: X X | B1 B1 | X B1                   : Pass: 0.5 Bet: 0.5
# 3: X X | B1 B1 | X B1 B1                : Pass: 0.5 Bet: 0.5
# 3: X X | B1 B1 | X B1 B1 | B1           : Pass: 0.5 Bet: 0.5
# 3: X X | B1 B1 | X B1 B1 | X            : Pass: 0.5 Bet: 0.5
# 3: X X | B1 B1 | X B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 3: X X | B1 B1 | X X                    : Pass: 0.5 Bet: 0.5
# 3: X X | B1 B1 | X X | B1               : Pass: 0.0 Bet: 1.0
# 3: X X | B1 B1 | X X | X                : Pass: 1.0 Bet: 0.0
# 3: X X | B1 B1 | X X | X B1             : Pass: 0.5 Bet: 0.5
# 3: X X | X                              : Pass: 0.9993 Bet: 0.0007
# 3: X X | X B1                           : Pass: 0.9999 Bet: 0.0001
# 3: X X | X B1 B1                        : Pass: 0.0721 Bet: 0.9279
# 3: X X | X B1 B1 | B1                   : Pass: 0.0305 Bet: 0.9695
# 3: X X | X B1 B1 | B1 B1                : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | B1 B1 | B1           : Pass: 0.0157 Bet: 0.9843
# 3: X X | X B1 B1 | B1 B1 | X            : Pass: 0.9843 Bet: 0.0157
# 3: X X | X B1 B1 | B1 B1 | X B1         : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | X                    : Pass: 0.6074 Bet: 0.3926
# 3: X X | X B1 B1 | X B1                 : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | X B1 B1              : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | X B1 B1 | B1         : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | X B1 B1 | X          : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | X B1 B1 | X B1       : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | X X                  : Pass: 0.5 Bet: 0.5
# 3: X X | X B1 B1 | X X | B1             : Pass: 0.3232 Bet: 0.6768
# 3: X X | X B1 B1 | X X | X              : Pass: 0.6768 Bet: 0.3232
# 3: X X | X B1 B1 | X X | X B1           : Pass: 0.5 Bet: 0.5
# 3: X X | X X                            : Pass: 0.9939 Bet: 0.0061
# 3: X X | X X | B1                       : Pass: 0.0 Bet: 1.0
# 3: X X | X X | B1 B1                    : Pass: 0.0055 Bet: 0.9945
# 3: X X | X X | B1 B1 | B1               : Pass: 0.0 Bet: 1.0
# 3: X X | X X | B1 B1 | X                : Pass: 1.0 Bet: 0.0
# 3: X X | X X | B1 B1 | X B1             : Pass: 0.5 Bet: 0.5
# 3: X X | X X | X                        : Pass: 1.0 Bet: 0.0
# 3: X X | X X | X B1                     : Pass: 1.0 Bet: 0.0
# 3: X X | X X | X B1 B1                  : Pass: 0.5 Bet: 0.5
# 3: X X | X X | X B1 B1 | B1             : Pass: 0.5 Bet: 0.5
# 3: X X | X X | X B1 B1 | X              : Pass: 0.5 Bet: 0.5
# 3: X X | X X | X B1 B1 | X B1           : Pass: 0.5 Bet: 0.5
# 3: X X | X X | X X                      : Pass: 0.0 Bet: 1.0
# 3: X X | X X | X X | B1                 : Pass: 0.0 Bet: 1.0
# 3: X X | X X | X X | X                  : Pass: 1.0 Bet: 0.0
# 3: X X | X X | X X | X B1               : Pass: 0.5 Bet: 0.5

# %% [markdown]
# TODO:
# Change terminal payoff state calculations
# Need limited betting rounds, as well as sizings. Now just choose pot.

# %% [markdown]
# CURRENT ASSUMPTIONS:
#
# - Stacks: INF
#
# - Bets: INF
#
# - Betting Rounds: 3

# %%
#Testing
initialNode = historyNode(None, -1, 0)
midNode = historyNode(historyNode(historyNode(initialNode, 1, 0), 1, 0), 1, 1)
terminalFoldNode = historyNode(midNode, 0, 1)
turnNode = historyNode(historyNode(historyNode(midNode, 1, 1), 1, 2), 1, 2)
riverNode = historyNode(historyNode(turnNode, 1, 3), 1, 3)
checksFuckNode = historyNode(historyNode(historyNode(initialNode, 0, 2), 1, 2), 0, 2)
retardNode = historyNode(historyNode(initialNode, 0, 2), 1, 2)
print(terminalNode(checksFuckNode))
print(checksFuckNode.historyLength())
print(roundTerminalNode(retardNode))
# Out:
# 0
# 1
# None
